# %%
import pandas as pd
import numpy as np
import yfinance as yf

start_date = "2017-01-01"
end_date = "2022-06-01"
symbol = "ETH-USD"
df = yf.download(symbol, start=start_date, end=end_date)

# Flatten the MultiIndex columns
df.columns = df.columns.get_level_values(1)

# add a column
df["Returns"] = df["Close"].pct_change() # calculatig oercentage change for the close column
df.dropna(inplace=True) # inplace=True overwrites the dataFrame
df["lrets"] = np.log(df["Close"] / df["Close"].shift(1))
df["lrets_cumsum"] = df["lrets"].cumsum()
df["rets_normal"] = np.exp(df["lrets_cumsum"]) - 1
df.drop(columns=["High", "Low", "Adj Close"], inplace=True)
df.fillna(0, inplace=True)
df = df.reset_index()
df.loc[df["Close"].shift(-1) > df["Close"], "TARGET"] = 1
df.loc[df["Close"].shift(-1) <= df["Close"], "TARGET"] = -1
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/algorithmic-trading-JD8T-zUW-py3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:228, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 14
#      11 df.columns = df.columns.get_level_values(1)
#      13 # add a column
# ...

# %%
df.loc[df["Close"].shift(-1) > df["Close"], "TARGET"] = 1
df.loc[df["Close"].shift(-1) <= df["Close"], "TARGET"] = -1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.loc[df["Close"].shift(-1) > df["Close"], "TARGET"] = 1
#       2 df.loc[df["Close"].shift(-1) <= df["Close"], "TARGET"] = -1
#
# File ~/Library/Caches/pypoetry/virtualenvs/algorithmic-trading-JD8T-zUW-py3.12/lib/python3.12/site-packages/pandas/core/indexing.py:907, in _LocationIndexer.__setitem__(self, key, value)
#     905     maybe_callable = com.apply_if_callable(key, self.obj)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907 indexer = self._get_setitem_indexer(key)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf

start_date = "2017-01-01"
end_date = "2022-06-01"
symbol = "ETH-USD"
df = yf.download(symbol, start=start_date, end=end_date)

# add a column
df["Returns"] = df["Close"].pct_change() # calculating percentage change for the close column
df.dropna(inplace=True) # inplace=True overwrites the dataFrame
df["lrets"] = np.log(df["Close"] / df["Close"].shift(1))
df["lrets_cumsum"] = df["lrets"].cumsum()
df["rets_normal"] = np.exp(df["lrets_cumsum"]) - 1
df.drop(columns=["High", "Low", "Adj Close"], inplace=True)
df.fillna(0, inplace=True)

# Create the TARGET column
df["TARGET"] = np.where(df["Close"].shift(-1) > df["Close"], 1, -1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price             Close         Open       Volume   Returns     lrets  \
# Ticker          ETH-USD      ETH-USD      ETH-USD
# Date
# 2017-11-10   299.252991   320.670990    885985984 -0.067411  0.000000
# 2017-11-11   314.681000   298.585999    842300992  0.051555  0.050270
# 2017-11-12   307.907990   314.690002   1613479936 -0.021523 -0.021758
# 2017-11-13   316.716003   307.024994   1041889984  0.028606  0.028204
# 2017-11-14   337.631012   316.763000   1069680000  0.066037  0.063948
# ...                 ...          ...          ...       ...       ...
# 2022-05-27  1724.922852  1802.543823  25470760032 -0.043788 -0.044776
# 2022-05-28  1757.941772  1724.635986  23214777872  0.019142  0.018961
# 2022-05-29  1812.031006  1792.184448  10642556101  0.030769  0.030305
# 2022-05-30  1996.441284  1811.885986  19580808705  0.101770  0.096918
# 2022-05-31  1942.328003  1996.408081  18363115560 -0.027105 -0.027479
#
# Price      lrets_cumsum rets_normal TARGET
# Ticker
# Date
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys

# Print versions for reference
print("Python version:", sys.version)
print("Pandas version:", pd.__version__)
print("Yfinance version:", yf.__version__)

start_date = "2017-01-01"
end_date = "2022-06-01"
symbol = "ETH-USD"
df = yf.download(symbol, start=start_date, end=end_date)

# Detailed debugging
print("\nOriginal DataFrame Info:")
print(df.info())

print("\nIndex Type:", type(df.index))
print("\nIndex Details:")
print(df.index)

# Create a copy of the DataFrame to avoid any in-place modification issues
df_copy = df.copy()

# Debugging shift operation
print("\nFirst few rows of Close prices:")
print(df['Close'].head())

print("\nFirst few rows of Shifted Close prices:")
shifted_close = df['Close'].shift(-1)
print(shifted_close.head())

# Attempt to create target column with explicit error handling
try:
    # Two-step approach
    df_copy.loc[df_copy["Close"].shift(-1) > df_copy["Close"], "TARGET"] = 1
    df_copy.loc[df_copy["Close"].shift(-1) <= df_copy["Close"], "TARGET"] = -1
    
    print("\nTarget column creation successful")
    print(df_copy["TARGET"].head())
except Exception as e:
    print("\nError Details:")
    print(type(e))
    print(str(e))
# Out:
# Python version: 3.12.7 (main, Oct  1 2024, 02:05:46) [Clang 15.0.0 (clang-1500.3.9.4)]
# Pandas version: 2.2.3
# Yfinance version: 0.2.50
# [*********************100%***********************]  1 of 1 completed
# Original DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1665 entries, 2017-11-09 to 2022-05-31
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, ETH-USD)  1665 non-null   float64
#  1   (Close, ETH-USD)      1665 non-null   float64
#  2   (High, ETH-USD)       1665 non-null   float64
#  3   (Low, ETH-USD)        1665 non-null   float64
#  4   (Open, ETH-USD)       1665 non-null   float64
#  5   (Volume, ETH-USD)     1665 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 91.1 KB
# None
#
# Index Type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#
# Index Details:
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf

start_date = "2017-01-01"
end_date = "2022-06-01"
symbol = "ETH-USD"
df = yf.download(symbol, start=start_date, end=end_date)

# Flatten the MultiIndex columns
df.columns = df.columns.get_level_values(1)

# Now proceed with your original operations
df["Returns"] = df["Close"].pct_change()
df.dropna(inplace=True)
df["lrets"] = np.log(df["Close"] / df["Close"].shift(1))
df["lrets_cumsum"] = df["lrets"].cumsum()
df["rets_normal"] = np.exp(df["lrets_cumsum"]) - 1
df.drop(columns=["High", "Low", "Adj Close"], inplace=True)
df.fillna(0, inplace=True)

# Now you can create the target column
df.loc[df["Close"].shift(-1) > df["Close"], "TARGET"] = 1
df.loc[df["Close"].shift(-1) <= df["Close"], "TARGET"] = -1
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/algorithmic-trading-JD8T-zUW-py3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:228, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 14
#      11 df.columns = df.columns.get_level_values(1)
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf

start_date = "2017-01-01"
end_date = "2022-06-01"
symbol = "ETH-USD"
df = yf.download(symbol, start=start_date, end=end_date)

# Print column names to verify
print("Original columns:", df.columns)

# Flatten the MultiIndex columns and reset the index
df.columns = [col[1] if isinstance(col, tuple) else col for col in df.columns]
df = df.reset_index()

# Now proceed with your operations
df["Returns"] = df["Close"].pct_change()
df.dropna(inplace=True)
df["lrets"] = np.log(df["Close"] / df["Close"].shift(1))
df["lrets_cumsum"] = df["lrets"].cumsum()
df["rets_normal"] = np.exp(df["lrets_cumsum"]) - 1
df.drop(columns=["High", "Low", "Adj Close"], inplace=True)
df.fillna(0, inplace=True)

# Create the target column
df.loc[df["Close"].shift(-1) > df["Close"], "TARGET"] = 1
df.loc[df["Close"].shift(-1) <= df["Close"], "TARGET"] = -1

# Verify the result
print("\nFinal DataFrame:")
print(df.head())
print("\nColumns:", df.columns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Original columns: MultiIndex([('Adj Close', 'ETH-USD'),
#             (    'Close', 'ETH-USD'),
#             (     'High', 'ETH-USD'),
#             (      'Low', 'ETH-USD'),
#             (     'Open', 'ETH-USD'),
#             (   'Volume', 'ETH-USD')],
#            names=['Price', 'Ticker'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/algorithmic-trading-JD8T-zUW-py3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf

start_date = "2017-01-01"
end_date = "2022-06-01"
symbol = "ETH-USD"

# Download the data with detailed error handling
try:
    df = yf.download(symbol, start=start_date, end=end_date)
    
    # Detailed column and index investigation
    print("DataFrame Info:")
    print(df.info())
    
    print("\nColumn Structure:")
    print(df.columns)
    print("\nColumn Types:")
    for col in df.columns:
        print(f"{col}: {type(col)}")
    
    print("\nIndex Type:", type(df.index))
    print("\nIndex Details:")
    print(df.index)

except Exception as e:
    print("Error downloading data:", e)
# Out:
# [*********************100%***********************]  1 of 1 completed
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1665 entries, 2017-11-09 to 2022-05-31
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, ETH-USD)  1665 non-null   float64
#  1   (Close, ETH-USD)      1665 non-null   float64
#  2   (High, ETH-USD)       1665 non-null   float64
#  3   (Low, ETH-USD)        1665 non-null   float64
#  4   (Open, ETH-USD)       1665 non-null   float64
#  5   (Volume, ETH-USD)     1665 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 91.1 KB
# None
#
# Column Structure:
# MultiIndex([('Adj Close', 'ETH-USD'),
#             (    'Close', 'ETH-USD'),
#             (     'High', 'ETH-USD'),
#             (      'Low', 'ETH-USD'),
#             (     'Open', 'ETH-USD'),
#             (   'Volume', 'ETH-USD')],
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf

start_date = "2017-01-01"
end_date = "2022-06-01"
symbol = "ETH-USD"
df = yf.download(symbol, start=start_date, end=end_date)

# Explicitly rename the columns
df.columns = ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

# Now proceed with your operations
df["Returns"] = df["Close"].pct_change()
df.dropna(inplace=True)
df["lrets"] = np.log(df["Close"] / df["Close"].shift(1))
df["lrets_cumsum"] = df["lrets"].cumsum()
df["rets_normal"] = np.exp(df["lrets_cumsum"]) - 1
df.drop(columns=["High", "Low", "Adj Close"], inplace=True)
df.fillna(0, inplace=True)

# Create the target column
df.loc[df["Close"].shift(-1) > df["Close"], "TARGET"] = 1
df.loc[df["Close"].shift(-1) <= df["Close"], "TARGET"] = -1

# Verify the result
print(df.head())
print("\nColumns:", df.columns)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close        Open      Volume   Returns     lrets  \
# Date
# 2017-11-10  299.252991  320.670990   885985984 -0.067411  0.000000
# 2017-11-11  314.681000  298.585999   842300992  0.051555  0.050270
# 2017-11-12  307.907990  314.690002  1613479936 -0.021523 -0.021758
# 2017-11-13  316.716003  307.024994  1041889984  0.028606  0.028204
# 2017-11-14  337.631012  316.763000  1069680000  0.066037  0.063948
#
#             lrets_cumsum  rets_normal  TARGET
# Date
# 2017-11-10      0.000000     0.000000     1.0
# 2017-11-11      0.050270     0.051555    -1.0
# 2017-11-12      0.028512     0.028922     1.0
# 2017-11-13      0.056716     0.058355     1.0
# 2017-11-14      0.120664     0.128246    -1.0
#
# Columns: Index(['Close', 'Open', 'Volume', 'Returns', 'lrets', 'lrets_cumsum',
#        'rets_normal', 'TARGET'],
#       dtype='object')
